# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os

print(os.getcwd())
# Out:
# d:\Samruddhi\CONTEXTUAL-PREDICTIVE-MAINTENANCE-IOT-EDGE-AI-\Src

# %%
import os

print(os.path.exists("Data/processed/feature_engineered.csv"))
# Out:
# False

# %%
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))

# %%
import os

print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# d:\Samruddhi\CONTEXTUAL-PREDICTIVE-MAINTENANCE-IOT-EDGE-AI-\Src

# %%
import os

print("\nCSV files found:")

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# CSV files found:

# %%
import os

print(os.path.exists("Data/processed/feature_engineered.csv"))
# Out:
# False

# %%
import pandas as pd

df = pd.read_csv("../Data/processed/feature_engineered.csv")

print("Dataset Loaded Successfully!")
df.head()
# Out:
# Dataset Loaded Successfully!
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    4     L47183    L                298.2                    308.6
# 1    5     L47184    L                298.2                    308.7
# 2    6     M14865    M                298.1                    308.6
# 3    7     L47186    L                298.1                    308.6
# 4    8     L47187    L                298.1                    308.6
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Machine failure  TWF  \
# 0                    1433         39.5                7                0    0
# 1                    1408         40.0                9                0    0
# 2                    1425         41.9               11                0    0
# 3                    1558         42.4               14                0    0
# 4                    1527         40.2               16                0    0
#
#    ...  Process temperature [K]_lag_3  Rotational speed [rpm]_lag_1  \
# 0  ...                          308.6                        1498.0
# 1  ...                          308.7                        1433.0
# 2  ...                          308.5                        1408.0
# 3  ...                          308.6                        1425.0
# 4  ...                          308.7                        1558.0
#
#    Rotational speed [rpm]_lag_2  Rotational speed [rpm]_lag_3  \
# 0                        1408.0                        1551.0
# 1                        1498.0                        1408.0
# 2                        1433.0                        1498.0
# 3                        1408.0                        1433.0
# 4                        1425.0                        1408.0
#
#    Torque [Nm]_lag_1  Torque [Nm]_lag_2  Torque [Nm]_lag_3  \
# 0               49.4               46.3               42.8
# 1               39.5               49.4               46.3
# 2               40.0               39.5               49.4
# 3               41.9               40.0               39.5
# 4               42.4               41.9               40.0
#
#    Tool wear [min]_lag_1  Tool wear [min]_lag_2  Tool wear [min]_lag_3
# 0                    5.0                    3.0                    0.0
# 1                    7.0                    5.0                    3.0
# 2                    9.0                    7.0                    5.0
# 3                   11.0                    9.0                    7.0
# 4                   14.0                   11.0                    9.0
#
# [5 rows x 39 columns]

# %%
print("Dataset Shape:")
print(df.shape)
# Out:
# Dataset Shape:
# (9997, 39)

# %%
print("Dataset Information:")
df.info()
# Out:
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 9997 entries, 0 to 9996
# Data columns (total 39 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   UDI                                9997 non-null   int64
#  1   Product ID                         9997 non-null   str
#  2   Type                               9997 non-null   str
#  3   Air temperature [K]                9997 non-null   float64
#  4   Process temperature [K]            9997 non-null   float64
#  5   Rotational speed [rpm]             9997 non-null   int64
#  6   Torque [Nm]                        9997 non-null   float64
#  7   Tool wear [min]                    9997 non-null   int64
#  8   Machine failure                    9997 non-null   int64
#  9   TWF                                9997 non-null   int64
#  10  HDF                                9997 non-null   int64
#  11  PWF                                9997 non-null   int64
#  12  OSF                                9997 non-null   int64
#  13  RNF                                9997 non-null   int64
#  14  Air temperature [K]_roll_mean      9997 non-null   float64
#  15  Air temperature [K]_roll_std       9997 non-null   float64
#  16  Process temperature [K]_roll_mean  9997 non-null   float64
#  17  Process temperature [K]_roll_std   9997 non-null   float64
#  18  Rotational speed [rpm]_roll_mean   9997 non-null   float64
#  19  Rotational speed [rpm]_roll_std    9997 non-null   float64
#  20  Torque [Nm]_roll_mean              9997 non-null   float64
#  21  Torque [Nm]_roll_std               9997 non-null   float64
#  22  Tool wear [min]_roll_mean          9997 non-null   float64
#  23  Tool wear [min]_roll_std           9997 non-null   float64
#  24  Air temperature [K]_lag_1          9997 non-null   float64
#  25  Air temperature [K]_lag_2          9997 non-null   float64
#  26  Air temperature [K]_lag_3          9997 non-null   float64
#  27  Process temperature [K]_lag_1      9997 non-null   float64
#  28  Process temperature [K]_lag_2      9997 non-null   float64
#  29  Process temperature [K]_lag_3      9997 non-null   float64
#  30  Rotational speed [rpm]_lag_1       9997 non-null   float64
#  31  Rotational speed [rpm]_lag_2       9997 non-null   float64
#  32  Rotational speed [rpm]_lag_3       9997 non-null   float64
#  33  Torque [Nm]_lag_1                  9997 non-null   float64
#  34  Torque [Nm]_lag_2                  9997 non-null   float64
#  35  Torque [Nm]_lag_3                  9997 non-null   float64
#  36  Tool wear [min]_lag_1              9997 non-null   float64
#  37  Tool wear [min]_lag_2              9997 non-null   float64
#  38  Tool wear [min]_lag_3              9997 non-null   float64
# dtypes: float64(28), int64(9), str(2)
# memory usage: 3.0 MB

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# UDI                                  0
# Product ID                           0
# Type                                 0
# Air temperature [K]                  0
# Process temperature [K]              0
# Rotational speed [rpm]               0
# Torque [Nm]                          0
# Tool wear [min]                      0
# Machine failure                      0
# TWF                                  0
# HDF                                  0
# PWF                                  0
# OSF                                  0
# RNF                                  0
# Air temperature [K]_roll_mean        0
# Air temperature [K]_roll_std         0
# Process temperature [K]_roll_mean    0
# Process temperature [K]_roll_std     0
# Rotational speed [rpm]_roll_mean     0
# Rotational speed [rpm]_roll_std      0
# Torque [Nm]_roll_mean                0
# Torque [Nm]_roll_std                 0
# Tool wear [min]_roll_mean            0
# Tool wear [min]_roll_std             0
# Air temperature [K]_lag_1            0
# Air temperature [K]_lag_2            0
# Air temperature [K]_lag_3            0
# Process temperature [K]_lag_1        0
# Process temperature [K]_lag_2        0
# Process temperature [K]_lag_3        0
# Rotational speed [rpm]_lag_1         0
# Rotational speed [rpm]_lag_2         0
# Rotational speed [rpm]_lag_3         0
# Torque [Nm]_lag_1                    0
# Torque [Nm]_lag_2                    0
# Torque [Nm]_lag_3                    0
# Tool wear [min]_lag_1                0
# Tool wear [min]_lag_2                0
# Tool wear [min]_lag_3                0
# dtype: int64

# %%
df.describe()
# Out:
#                 UDI  Air temperature [K]  Process temperature [K]  \
# count   9997.000000          9997.000000              9997.000000
# mean    5002.000000           300.005492               310.005982
# std     2886.029655             2.000296                 1.483756
# min        4.000000           295.300000               305.700000
# 25%     2503.000000           298.300000               308.800000
# 50%     5002.000000           300.100000               310.100000
# 75%     7501.000000           301.500000               311.100000
# max    10000.000000           304.500000               313.800000
#
#        Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Machine failure  \
# count             9997.000000  9997.000000      9997.000000      9997.000000
# mean              1538.792038    39.985056       107.982595         0.033910
# std                179.305720     9.969745        63.637547         0.181007
# min               1168.000000     3.800000         0.000000         0.000000
# 25%               1423.000000    33.200000        53.000000         0.000000
# 50%               1503.000000    40.100000       108.000000         0.000000
# 75%               1612.000000    46.800000       162.000000         0.000000
# max               2886.000000    76.600000       253.000000         1.000000
#
#                TWF          HDF          PWF  ...  \
# count  9997.000000  9997.000000  9997.000000  ...
# mean      0.004601     0.011503     0.009503  ...
# std       0.067681     0.106641     0.097023  ...
# min       0.000000     0.000000     0.000000  ...
# 25%       0.000000     0.000000     0.000000  ...
# 50%       0.000000     0.000000     0.000000  ...
# 75%       0.000000     0.000000     0.000000  ...
# max       1.000000     1.000000     1.000000  ...
#
#        Process temperature [K]_lag_3  Rotational speed [rpm]_lag_1  \
# count                    9997.000000                   9997.000000
# mean                      310.005962                   1538.791838
# std                         1.483775                    179.305765
# min                       305.700000                   1168.000000
# 25%                       308.800000                   1423.000000
# 50%                       310.100000                   1503.000000
# 75%                       311.100000                   1612.000000
# max                       313.800000                   2886.000000
#
#        Rotational speed [rpm]_lag_2  Rotational speed [rpm]_lag_3  \
# count                   9997.000000                   9997.000000
# mean                    1538.791838                   1538.782435
# std                      179.305765                    179.302659
# min                     1168.000000                   1168.000000
# 25%                     1423.000000                   1423.000000
# 50%                     1503.000000                   1503.000000
# 75%                     1612.000000                   1612.000000
# max                     2886.000000                   2886.000000
#
#        Torque [Nm]_lag_1  Torque [Nm]_lag_2  Torque [Nm]_lag_3  \
# count        9997.000000        9997.000000        9997.000000
# mean           39.985976          39.985756          39.986696
# std             9.970190           9.970026           9.969848
# min             3.800000           3.800000           3.800000
# 25%            33.200000          33.200000          33.200000
# 50%            40.100000          40.100000          40.100000
# 75%            46.800000          46.800000          46.800000
# max            76.600000          76.600000          76.600000
#
#        Tool wear [min]_lag_1  Tool wear [min]_lag_2  Tool wear [min]_lag_3
# count            9997.000000            9997.000000            9997.000000
# mean              107.980094             107.977893             107.975693
# std                63.641103              63.644353              63.647706
# min                 0.000000               0.000000               0.000000
# 25%                53.000000              53.000000              53.000000
# 50%               108.000000             108.000000             108.000000
# 75%               162.000000             162.000000             162.000000
# max               253.000000             253.000000             253.000000
#
# [8 rows x 37 columns]

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
import matplotlib.pyplot as plt

df["Machine failure"].value_counts().plot(kind="bar")

plt.title("Machine Failure Distribution")
plt.xlabel("Machine Failure")
plt.ylabel("Count")
plt.show()

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(12,10))

plt.imshow(corr)

plt.colorbar()

plt.xticks(range(len(corr.columns)), corr.columns, rotation=90, fontsize=7)
plt.yticks(range(len(corr.columns)), corr.columns, fontsize=7)

plt.title("Correlation Matrix")

plt.show()

# %%
df.hist(figsize=(16,12))

plt.tight_layout()

plt.show()

# %%
columns = [
    "Air temperature [K]",
    "Process temperature [K]",
    "Rotational speed [rpm]",
    "Torque [Nm]",
    "Tool wear [min]"
]

for col in columns:
    plt.figure(figsize=(5,3))
    plt.boxplot(df[col])
    plt.title(col)
    plt.show()

# %%
import pandas as pd

df = pd.read_csv("../Data/processed/feature_engineered.csv")

print(df.shape)
df.head()
# Out:
# (9997, 39)
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    4     L47183    L                298.2                    308.6
# 1    5     L47184    L                298.2                    308.7
# 2    6     M14865    M                298.1                    308.6
# 3    7     L47186    L                298.1                    308.6
# 4    8     L47187    L                298.1                    308.6
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Machine failure  TWF  \
# 0                    1433         39.5                7                0    0
# 1                    1408         40.0                9                0    0
# 2                    1425         41.9               11                0    0
# 3                    1558         42.4               14                0    0
# 4                    1527         40.2               16                0    0
#
#    ...  Process temperature [K]_lag_3  Rotational speed [rpm]_lag_1  \
# 0  ...                          308.6                        1498.0
# 1  ...                          308.7                        1433.0
# 2  ...                          308.5                        1408.0
# 3  ...                          308.6                        1425.0
# 4  ...                          308.7                        1558.0
#
#    Rotational speed [rpm]_lag_2  Rotational speed [rpm]_lag_3  \
# 0                        1408.0                        1551.0
# 1                        1498.0                        1408.0
# 2                        1433.0                        1498.0
# 3                        1408.0                        1433.0
# 4                        1425.0                        1408.0
#
#    Torque [Nm]_lag_1  Torque [Nm]_lag_2  Torque [Nm]_lag_3  \
# 0               49.4               46.3               42.8
# 1               39.5               49.4               46.3
# 2               40.0               39.5               49.4
# 3               41.9               40.0               39.5
# 4               42.4               41.9               40.0
#
#    Tool wear [min]_lag_1  Tool wear [min]_lag_2  Tool wear [min]_lag_3
# 0                    5.0                    3.0                    0.0
# 1                    7.0                    5.0                    3.0
# 2                    9.0                    7.0                    5.0
# 3                   11.0                    9.0                    7.0
# 4                   14.0                   11.0                    9.0
#
# [5 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9997 entries, 0 to 9996
# Data columns (total 39 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   UDI                                9997 non-null   int64
#  1   Product ID                         9997 non-null   str
#  2   Type                               9997 non-null   str
#  3   Air temperature [K]                9997 non-null   float64
#  4   Process temperature [K]            9997 non-null   float64
#  5   Rotational speed [rpm]             9997 non-null   int64
#  6   Torque [Nm]                        9997 non-null   float64
#  7   Tool wear [min]                    9997 non-null   int64
#  8   Machine failure                    9997 non-null   int64
#  9   TWF                                9997 non-null   int64
#  10  HDF                                9997 non-null   int64
#  11  PWF                                9997 non-null   int64
#  12  OSF                                9997 non-null   int64
#  13  RNF                                9997 non-null   int64
#  14  Air temperature [K]_roll_mean      9997 non-null   float64
#  15  Air temperature [K]_roll_std       9997 non-null   float64
#  16  Process temperature [K]_roll_mean  9997 non-null   float64
#  17  Process temperature [K]_roll_std   9997 non-null   float64
#  18  Rotational speed [rpm]_roll_mean   9997 non-null   float64
#  19  Rotational speed [rpm]_roll_std    9997 non-null   float64
#  20  Torque [Nm]_roll_mean              9997 non-null   float64
#  21  Torque [Nm]_roll_std               9997 non-null   float64
#  22  Tool wear [min]_roll_mean          9997 non-null   float64
#  23  Tool wear [min]_roll_std           9997 non-null   float64
#  24  Air temperature [K]_lag_1          9997 non-null   float64
#  25  Air temperature [K]_lag_2          9997 non-null   float64
#  26  Air temperature [K]_lag_3          9997 non-null   float64
#  27  Process temperature [K]_lag_1      9997 non-null   float64
#  28  Process temperature [K]_lag_2      9997 non-null   float64
#  29  Process temperature [K]_lag_3      9997 non-null   float64
#  30  Rotational speed [rpm]_lag_1       9997 non-null   float64
#  31  Rotational speed [rpm]_lag_2       9997 non-null   float64
#  32  Rotational speed [rpm]_lag_3       9997 non-null   float64
#  33  Torque [Nm]_lag_1                  9997 non-null   float64
#  34  Torque [Nm]_lag_2                  9997 non-null   float64
#  35  Torque [Nm]_lag_3                  9997 non-null   float64
#  36  Tool wear [min]_lag_1              9997 non-null   float64
#  37  Tool wear [min]_lag_2              9997 non-null   float64
#  38  Tool wear [min]_lag_3              9997 non-null   float64
# dtypes: float64(28), int64(9), str(2)
# memory usage: 3.0 MB

# %%
df.isnull().sum()
# Out:
# UDI                                  0
# Product ID                           0
# Type                                 0
# Air temperature [K]                  0
# Process temperature [K]              0
# Rotational speed [rpm]               0
# Torque [Nm]                          0
# Tool wear [min]                      0
# Machine failure                      0
# TWF                                  0
# HDF                                  0
# PWF                                  0
# OSF                                  0
# RNF                                  0
# Air temperature [K]_roll_mean        0
# Air temperature [K]_roll_std         0
# Process temperature [K]_roll_mean    0
# Process temperature [K]_roll_std     0
# Rotational speed [rpm]_roll_mean     0
# Rotational speed [rpm]_roll_std      0
# Torque [Nm]_roll_mean                0
# Torque [Nm]_roll_std                 0
# Tool wear [min]_roll_mean            0
# Tool wear [min]_roll_std             0
# Air temperature [K]_lag_1            0
# Air temperature [K]_lag_2            0
# Air temperature [K]_lag_3            0
# Process temperature [K]_lag_1        0
# Process temperature [K]_lag_2        0
# Process temperature [K]_lag_3        0
# Rotational speed [rpm]_lag_1         0
# Rotational speed [rpm]_lag_2         0
# Rotational speed [rpm]_lag_3         0
# Torque [Nm]_lag_1                    0
# Torque [Nm]_lag_2                    0
# Torque [Nm]_lag_3                    0
# Tool wear [min]_lag_1                0
# Tool wear [min]_lag_2                0
# Tool wear [min]_lag_3                0
# dtype: int64

# %%
df.describe()
# Out:
#                 UDI  Air temperature [K]  Process temperature [K]  \
# count   9997.000000          9997.000000              9997.000000
# mean    5002.000000           300.005492               310.005982
# std     2886.029655             2.000296                 1.483756
# min        4.000000           295.300000               305.700000
# 25%     2503.000000           298.300000               308.800000
# 50%     5002.000000           300.100000               310.100000
# 75%     7501.000000           301.500000               311.100000
# max    10000.000000           304.500000               313.800000
#
#        Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Machine failure  \
# count             9997.000000  9997.000000      9997.000000      9997.000000
# mean              1538.792038    39.985056       107.982595         0.033910
# std                179.305720     9.969745        63.637547         0.181007
# min               1168.000000     3.800000         0.000000         0.000000
# 25%               1423.000000    33.200000        53.000000         0.000000
# 50%               1503.000000    40.100000       108.000000         0.000000
# 75%               1612.000000    46.800000       162.000000         0.000000
# max               2886.000000    76.600000       253.000000         1.000000
#
#                TWF          HDF          PWF  ...  \
# count  9997.000000  9997.000000  9997.000000  ...
# mean      0.004601     0.011503     0.009503  ...
# std       0.067681     0.106641     0.097023  ...
# min       0.000000     0.000000     0.000000  ...
# 25%       0.000000     0.000000     0.000000  ...
# 50%       0.000000     0.000000     0.000000  ...
# 75%       0.000000     0.000000     0.000000  ...
# max       1.000000     1.000000     1.000000  ...
#
#        Process temperature [K]_lag_3  Rotational speed [rpm]_lag_1  \
# count                    9997.000000                   9997.000000
# mean                      310.005962                   1538.791838
# std                         1.483775                    179.305765
# min                       305.700000                   1168.000000
# 25%                       308.800000                   1423.000000
# 50%                       310.100000                   1503.000000
# 75%                       311.100000                   1612.000000
# max                       313.800000                   2886.000000
#
#        Rotational speed [rpm]_lag_2  Rotational speed [rpm]_lag_3  \
# count                   9997.000000                   9997.000000
# mean                    1538.791838                   1538.782435
# std                      179.305765                    179.302659
# min                     1168.000000                   1168.000000
# 25%                     1423.000000                   1423.000000
# 50%                     1503.000000                   1503.000000
# 75%                     1612.000000                   1612.000000
# max                     2886.000000                   2886.000000
#
#        Torque [Nm]_lag_1  Torque [Nm]_lag_2  Torque [Nm]_lag_3  \
# count        9997.000000        9997.000000        9997.000000
# mean           39.985976          39.985756          39.986696
# std             9.970190           9.970026           9.969848
# min             3.800000           3.800000           3.800000
# 25%            33.200000          33.200000          33.200000
# 50%            40.100000          40.100000          40.100000
# 75%            46.800000          46.800000          46.800000
# max            76.600000          76.600000          76.600000
#
#        Tool wear [min]_lag_1  Tool wear [min]_lag_2  Tool wear [min]_lag_3
# count            9997.000000            9997.000000            9997.000000
# mean              107.980094             107.977893             107.975693
# std                63.641103              63.644353              63.647706
# min                 0.000000               0.000000               0.000000
# 25%                53.000000              53.000000              53.000000
# 50%               108.000000             108.000000             108.000000
# 75%               162.000000             162.000000             162.000000
# max               253.000000             253.000000             253.000000
#
# [8 rows x 37 columns]

# %%
target = "Machine failure"

corr = df.corr(numeric_only=True)

importance = (
    corr[target]
    .drop(target)
    .abs()
    .sort_values(ascending=False)
)

importance.head(20)
# Out:
# HDF                                0.575798
# OSF                                0.531081
# PWF                                0.522810
# TWF                                0.362902
# Torque [Nm]                        0.191370
# Torque [Nm]_roll_std               0.149885
# Torque [Nm]_roll_mean              0.111443
# Tool wear [min]_roll_mean          0.106579
# Tool wear [min]                    0.105399
# Tool wear [min]_lag_1              0.103221
# Tool wear [min]_lag_2              0.101155
# Tool wear [min]_lag_3              0.095191
# Rotational speed [rpm]_roll_std    0.094066
# Air temperature [K]                0.082514
# Air temperature [K]_lag_1          0.082465
# Air temperature [K]_roll_mean      0.082365
# Air temperature [K]_lag_2          0.082056
# Air temperature [K]_lag_3          0.082006
# Rotational speed [rpm]             0.044206
# Process temperature [K]            0.035898
# Name: Machine failure, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

importance.head(15).plot(kind="barh")

plt.title("Top 15 Important Features")
plt.xlabel("Correlation with Machine Failure")
plt.gca().invert_yaxis()

plt.show()

# %%
importance.to_csv("../Reports/feature_importance.csv")

print("Saved successfully!")
# Out:
# Saved successfully!
